# %%
import netCDF4 as nc
from netCDF4 import Dataset
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
import openpyxl
import os

# %%
#####################################################################
# Reading a single ndtcdf like pdsi.nc which consists all the years #
#####################################################################


# Read the Excel file
file_path = 'location/locations.xlsx'  
df = pd.read_excel(file_path)


# Iterate over each row and print the values
for index, row in df.iterrows():
    location = row['location']
    latitude = row['Latitude']
    longitude = row['Longitude']

    # Open the NetCDF file
    dataset = nc.Dataset(f'./nc_files/rmax.nc', 'r')

    print(dataset.variables.keys())
    print("\nVariables and their dimensions:")

    print("Description of each variable:")
    for var in dataset.variables:
        # Fetch the variable object
        variable = dataset.variables[var]
        # Extract description attributes, defaulting to 'N/A' if not present
        long_name = variable.long_name if hasattr(variable, 'long_name') else 'N/A'
        units = variable.units if hasattr(variable, 'units') else 'N/A'
        print(f"{var}:")
        print(f"  Long Name: {long_name}")
        print(f"  Units: {units}\n")
    # Don't forget to close the dataset
    dataset.close()

    dataset = nc.Dataset(f'./nc_files/spei14d.nc', 'r')
    # Retrieve the latitude and longitude data
    lat = dataset.variables['lat'][:]
    lon = dataset.variables['lon'][:]

    # Your location's latitude and longitude
    location_lat =  latitude # Replace with the specific latitude
    location_lon = longitude  # Replace with the specific longitude

    # Find the nearest index for the specified location
    lat_idx = np.abs(lat - location_lat).argmin()
    lon_idx = np.abs(lon - location_lon).argmin()

    # Retrieve climate variable for all times for the specified location
    climate_variable = dataset.variables['spei'][:, lat_idx, lon_idx]  # Assuming time is the first dimension

    # Convert to a DataFrame
    df = pd.DataFrame({
        'data': climate_variable
    })


    #Temperature in gridMET is in Kelvin. Convert it to celsius. If you don't have temperature netcdf file, then comment the line below
    #df = df - 273.15


    lat_num = lat[lat_idx]
    lon_num = lon[lon_idx]
    print(lat_num,lon_num)
    df.columns = ['data']

    # Assuming the reference date is January 1, 1900
    reference_date = datetime(1900, 1, 1)

    days = dataset.variables['day'][:]
    # Convert days array to pandas Series
    days_series = pd.Series(days)

    # Convert to Gregorian dates using vectorized operations
    gregorian_dates_pd = reference_date + pd.to_timedelta(days_series, unit='D')

    days = gregorian_dates_pd

    df['dates'] = days
    df_new = df[['dates','data']]
    df_new.columns = ['date', 'rmax']
    df_new.to_excel(f'{location}.xlsx',index = False)



dir1 = './'
dir2 = './'

excel_files = os.listdir(dir1)

for file_name in excel_files:
    if file_name.endswith('.xlsx') or file_name.endswith('.xls'):
        file_path = os.path.join(dir1, file_name)
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'], errors='coerce')
        df_filtered = df[(df['date'].dt.year < 1980) | (df['date'].dt.year > 2003)]
        df_filtered = df_filtered[df_filtered['date'].dt.year.between(2004, 2020)]
        output_file_path = os.path.join(dir2, file_name)
        df_filtered.to_excel(output_file_path, index=False)
        print(f"Filtered data saved to: {output_file_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 18
#      15 longitude = row['Longitude']
#      17 # Open the NetCDF file
# ---> 18 dataset = nc.Dataset(f'./nc_files/rmax.nc', 'r')
#      20 print(dataset.variables.keys())
#      21 print("\nVariables and their dimensions:")
#
# File src\\netCDF4\\_netCDF4.pyx:2463, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\\netCDF4\\_netCDF4.pyx:2026, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'./nc_files/rmax.nc'

# %%
##########################################################################################
# Read netcdf file and Save file for each individual year in the same place as code path #
##########################################################################################

# Read the Excel file
file_path = 'location/locations.xlsx'  
df = pd.read_excel(file_path)

# Iterate over each row and print the values
for index, row in df.iterrows():
    location = row['location']
    latitude = row['Latitude']
    longitude = row['Longitude']

    years = list(range(2004, 2021))
    #years = [2020]
    for year in years:
        # Open the NetCDF file
        dataset = nc.Dataset(f'./nc_files/vpd_{year}.nc', 'r')

        print(dataset.variables.keys())
        print("\nVariables and their dimensions:")

        print("Description of each variable:")
        for var in dataset.variables:
            # Fetch the variable object
            variable = dataset.variables[var]
            # Extract description attributes, defaulting to 'N/A' if not present
            long_name = variable.long_name if hasattr(variable, 'long_name') else 'N/A'
            units = variable.units if hasattr(variable, 'units') else 'N/A'
            print(f"{var}:")
            print(f"  Long Name: {long_name}")
            print(f"  Units: {units}\n")

        # Don't forget to close the dataset
        dataset.close()

        dataset = nc.Dataset(f'./nc_files/vpd_{year}.nc', 'r')
        # Retrieve the latitude and longitude data
        lat = dataset.variables['lat'][:]
        lon = dataset.variables['lon'][:]

        # Your location's latitude and longitude
        location_lat =  latitude # Replace with the specific latitude
        location_lon = longitude  # Replace with the specific longitude

        # Find the nearest index for the specified location
        lat_idx = np.abs(lat - location_lat).argmin()
        lon_idx = np.abs(lon - location_lon).argmin()

        # Retrieve climate variable for all times for the specified location
        climate_variable = dataset.variables['mean_vapor_pressure_deficit'][:, lat_idx, lon_idx]  # Assuming time is the first dimension

        # Convert to a DataFrame
        df = pd.DataFrame({
            'data': climate_variable
        })


        #Temperature in gridMET is in Kelvin. Convert it to celsius. If you don't have temperature netcdf file, then comment the line below
        #df = df - 273.15


        lat_num = lat[lat_idx]
        lon_num = lon[lon_idx]
        print(lat_num,lon_num)
        df.columns = ['data']

        # Assuming the reference date is January 1, 1900
        reference_date = datetime(1900, 1, 1)

        days = dataset.variables['day'][:]
        # Convert days array to pandas Series
        days_series = pd.Series(days)

        # Convert to Gregorian dates using vectorized operations
        gregorian_dates_pd = reference_date + pd.to_timedelta(days_series, unit='D')

        days = gregorian_dates_pd

        df['dates'] = days
        df_new = df[['dates','data']]
        df_new.columns = ['date', 'vpd']
        df_new.to_excel(f'{location}{year}.xlsx',index = False)
# Out:
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -118.93333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 45.983333333333334 -120.30833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.31666666666667 -117.97499996666667
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.81666666666667 -117.64166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.400000000000006 -117.18333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.108333333333334 -117.05833330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.108333333333334 -119.51666663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
# ...
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -119.43333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -119.43333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.69166666666667 -119.43333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 46.94166666666667 -117.68333330000002
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334
# dict_keys(['lon', 'lat', 'day', 'crs', 'mean_vapor_pressure_deficit'])
#
# Variables and their dimensions:
# Description of each variable:
# lon:
#   Long Name: longitude
#   Units: degrees_east
#
# lat:
#   Long Name: latitude
#   Units: degrees_north
#
# day:
#   Long Name: time
#   Units: days since 1900-01-01 00:00:00
#
# crs:
#   Long Name: WGS 84
#   Units: N/A
#
# mean_vapor_pressure_deficit:
#   Long Name: vpd
#   Units: kPa
#
# 47.31666666666667 -117.39166663333334

# %%
df_new
# Out:
#           date   vs
# 0   2020-01-01  8.5
# 1   2020-01-02  4.8
# 2   2020-01-03  4.0
# 3   2020-01-04  7.7
# 4   2020-01-05  5.0
# ..         ...  ...
# 361 2020-12-27  2.7
# 362 2020-12-28  1.8
# 363 2020-12-29  1.6
# 364 2020-12-30  2.0
# 365 2020-12-31  4.0
#
# [366 rows x 2 columns]

# %%
######################################################################################
#Merge all years for each location and save them to variable named folder            #
######################################################################################


# Read the Excel file containing the list of locations
file_path = 'location/locations.xlsx'
df = pd.read_excel(file_path)
locations = df['location']

# Directory where the final merged files will be saved
output_dir = './vpd'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Loop through each location
for loc in locations:
    # Clean up location name if necessary
    loc_clean = loc.strip()

    # File paths for the four Excel files
    files = [f'{loc_clean}{year}.xlsx' for year in range(2004, 2021)]

    # Initialize an empty list to store the DataFrames
    dataframes = []

    # Loop through the file paths and read the files into DataFrames
    for file in files:
        if os.path.exists(file):
            df_temp = pd.read_excel(file)
            dataframes.append(df_temp)
            print(f"File {file} read successfully.")
        else:
            print(f"File {file} not found, skipping.")

    # If we have any DataFrames, merge them
    if dataframes:
        merged_df = pd.concat(dataframes, axis=0)
        merged_df.reset_index(drop=True, inplace=True)

        # Write the merged DataFrame to a new Excel file
        output_file = os.path.join(output_dir, f'{loc_clean}.xlsx')
        merged_df.to_excel(output_file, index=False)
        print(f"Files merged successfully into {output_file}")
    else:
        print(f"No valid files found for location {loc_clean}, skipping merge.")
# Out:
# File Almira2004.xlsx read successfully.
# File Almira2005.xlsx read successfully.
# File Almira2006.xlsx read successfully.
# File Almira2007.xlsx read successfully.
# File Almira2008.xlsx read successfully.
# File Almira2009.xlsx read successfully.
# File Almira2010.xlsx read successfully.
# File Almira2011.xlsx read successfully.
# File Almira2012.xlsx read successfully.
# File Almira2013.xlsx read successfully.
# File Almira2014.xlsx read successfully.
# File Almira2015.xlsx read successfully.
# File Almira2016.xlsx read successfully.
# File Almira2017.xlsx read successfully.
# File Almira2018.xlsx read successfully.
# File Almira2019.xlsx read successfully.
# File Almira2020.xlsx read successfully.
# Files merged successfully into ./vpd\Almira.xlsx
# File Bickleton2004.xlsx read successfully.
# File Bickleton2005.xlsx read successfully.
# File Bickleton2006.xlsx read successfully.
# File Bickleton2007.xlsx read successfully.
# File Bickleton2008.xlsx read successfully.
# File Bickleton2009.xlsx read successfully.
# File Bickleton2010.xlsx read successfully.
# File Bickleton2011.xlsx read successfully.
# File Bickleton2012.xlsx read successfully.
# File Bickleton2013.xlsx read successfully.
# File Bickleton2014.xlsx read successfully.
# File Bickleton2015.xlsx read successfully.
# File Bickleton2016.xlsx read successfully.
# File Bickleton2017.xlsx read successfully.
# File Bickleton2018.xlsx read successfully.
# File Bickleton2019.xlsx read successfully.
# File Bickleton2020.xlsx read successfully.
# Files merged successfully into ./vpd\Bickleton.xlsx
# File Dayton2004.xlsx read successfully.
# File Dayton2005.xlsx read successfully.
# File Dayton2006.xlsx read successfully.
# File Dayton2007.xlsx read successfully.
# File Dayton2008.xlsx read successfully.
# File Dayton2009.xlsx read successfully.
# File Dayton2010.xlsx read successfully.
# File Dayton2011.xlsx read successfully.
# File Dayton2012.xlsx read successfully.
# File Dayton2013.xlsx read successfully.
# File Dayton2014.xlsx read successfully.
# File Dayton2015.xlsx read successfully.
# File Dayton2016.xlsx read successfully.
# File Dayton2017.xlsx read successfully.
# File Dayton2018.xlsx read successfully.
# File Dayton2019.xlsx read successfully.
# File Dayton2020.xlsx read successfully.
# Files merged successfully into ./vpd\Dayton.xlsx
# File Dusty2004.xlsx read successfully.
# File Dusty2005.xlsx read successfully.
# File Dusty2006.xlsx read successfully.
# File Dusty2007.xlsx read successfully.
# File Dusty2008.xlsx read successfully.
# File Dusty2009.xlsx read successfully.
# File Dusty2010.xlsx read successfully.
# File Dusty2011.xlsx read successfully.
# File Dusty2012.xlsx read successfully.
# File Dusty2013.xlsx read successfully.
# File Dusty2014.xlsx read successfully.
# File Dusty2015.xlsx read successfully.
# File Dusty2016.xlsx read successfully.
# File Dusty2017.xlsx read successfully.
# File Dusty2018.xlsx read successfully.
# File Dusty2019.xlsx read successfully.
# File Dusty2020.xlsx read successfully.
# Files merged successfully into ./vpd\Dusty.xlsx
# File Fairfield2004.xlsx read successfully.
# File Fairfield2005.xlsx read successfully.
# File Fairfield2006.xlsx read successfully.
# File Fairfield2007.xlsx read successfully.
# File Fairfield2008.xlsx read successfully.
# File Fairfield2009.xlsx read successfully.
# File Fairfield2010.xlsx read successfully.
# File Fairfield2011.xlsx read successfully.
# File Fairfield2012.xlsx read successfully.
# File Fairfield2013.xlsx read successfully.
# File Fairfield2014.xlsx read successfully.
# File Fairfield2015.xlsx read successfully.
# File Fairfield2016.xlsx read successfully.
# File Fairfield2017.xlsx read successfully.
# File Fairfield2018.xlsx read successfully.
# File Fairfield2019.xlsx read successfully.
# File Fairfield2020.xlsx read successfully.
# Files merged successfully into ./vpd\Fairfield.xlsx
# File Farmington2004.xlsx read successfully.
# File Farmington2005.xlsx read successfully.
# File Farmington2006.xlsx read successfully.
# File Farmington2007.xlsx read successfully.
# File Farmington2008.xlsx read successfully.
# File Farmington2009.xlsx read successfully.
# File Farmington2010.xlsx read successfully.
# File Farmington2011.xlsx read successfully.
# File Farmington2012.xlsx read successfully.
# File Farmington2013.xlsx read successfully.
# File Farmington2014.xlsx read successfully.
# File Farmington2015.xlsx read successfully.
# File Farmington2016.xlsx read successfully.
# File Farmington2017.xlsx read successfully.
# File Farmington2018.xlsx read successfully.
# File Farmington2019.xlsx read successfully.
# File Farmington2020.xlsx read successfully.
# Files merged successfully into ./vpd\Farmington.xlsx
# File Horse Heaven2004.xlsx read successfully.
# File Horse Heaven2005.xlsx read successfully.
# File Horse Heaven2006.xlsx read successfully.
# File Horse Heaven2007.xlsx read successfully.
# File Horse Heaven2008.xlsx read successfully.
# File Horse Heaven2009.xlsx read successfully.
# File Horse Heaven2010.xlsx read successfully.
# File Horse Heaven2011.xlsx read successfully.
# File Horse Heaven2012.xlsx read successfully.
# File Horse Heaven2013.xlsx read successfully.
# File Horse Heaven2014.xlsx read successfully.
# File Horse Heaven2015.xlsx read successfully.
# File Horse Heaven2016.xlsx read successfully.
# File Horse Heaven2017.xlsx read successfully.
# File Horse Heaven2018.xlsx read successfully.
# File Horse Heaven2019.xlsx read successfully.
# File Horse Heaven2020.xlsx read successfully.
# Files merged successfully into ./vpd\Horse Heaven.xlsx
# File Lamont2004.xlsx read successfully.
# File Lamont2005.xlsx read successfully.
# File Lamont2006.xlsx read successfully.
# File Lamont2007.xlsx read successfully.
# File Lamont2008.xlsx read successfully.
# File Lamont2009.xlsx read successfully.
# File Lamont2010.xlsx read successfully.
# File Lamont2011.xlsx read successfully.
# File Lamont2012.xlsx read successfully.
# File Lamont2013.xlsx read successfully.
# File Lamont2014.xlsx read successfully.
# File Lamont2015.xlsx read successfully.
# File Lamont2016.xlsx read successfully.
# File Lamont2017.xlsx read successfully.
# File Lamont2018.xlsx read successfully.
# File Lamont2019.xlsx read successfully.
# File Lamont2020.xlsx read successfully.
# Files merged successfully into ./vpd\Lamont.xlsx
# File Lind2004.xlsx read successfully.
# File Lind2005.xlsx read successfully.
# File Lind2006.xlsx read successfully.
# File Lind2007.xlsx read successfully.
# File Lind2008.xlsx read successfully.
# File Lind2009.xlsx read successfully.
# File Lind2010.xlsx read successfully.
# File Lind2011.xlsx read successfully.
# File Lind2012.xlsx read successfully.
# File Lind2013.xlsx read successfully.
# File Lind2014.xlsx read successfully.
# File Lind2015.xlsx read successfully.
# File Lind2016.xlsx read successfully.
# File Lind2017.xlsx read successfully.
# File Lind2018.xlsx read successfully.
# File Lind2019.xlsx read successfully.
# File Lind2020.xlsx read successfully.
# Files merged successfully into ./vpd\Lind.xlsx
# File Mayview2004.xlsx read successfully.
# File Mayview2005.xlsx read successfully.
# File Mayview2006.xlsx read successfully.
# File Mayview2007.xlsx read successfully.
# File Mayview2008.xlsx read successfully.
# File Mayview2009.xlsx read successfully.
# File Mayview2010.xlsx read successfully.
# File Mayview2011.xlsx read successfully.
# File Mayview2012.xlsx read successfully.
# File Mayview2013.xlsx read successfully.
# File Mayview2014.xlsx read successfully.
# File Mayview2015.xlsx read successfully.
# File Mayview2016.xlsx read successfully.
# File Mayview2017.xlsx read successfully.
# File Mayview2018.xlsx read successfully.
# File Mayview2019.xlsx read successfully.
# File Mayview2020.xlsx read successfully.
# Files merged successfully into ./vpd\Mayview.xlsx
# File Pullman2004.xlsx read successfully.
# File Pullman2005.xlsx read successfully.
# File Pullman2006.xlsx read successfully.
# File Pullman2007.xlsx read successfully.
# File Pullman2008.xlsx read successfully.
# File Pullman2009.xlsx read successfully.
# File Pullman2010.xlsx read successfully.
# File Pullman2011.xlsx read successfully.
# File Pullman2012.xlsx read successfully.
# File Pullman2013.xlsx read successfully.
# File Pullman2014.xlsx read successfully.
# File Pullman2015.xlsx read successfully.
# File Pullman2016.xlsx read successfully.
# File Pullman2017.xlsx read successfully.
# File Pullman2018.xlsx read successfully.
# File Pullman2019.xlsx read successfully.
# File Pullman2020.xlsx read successfully.
# Files merged successfully into ./vpd\Pullman.xlsx
# File Reardan2004.xlsx read successfully.
# File Reardan2005.xlsx read successfully.
# File Reardan2006.xlsx read successfully.
# File Reardan2007.xlsx read successfully.
# File Reardan2008.xlsx read successfully.
# File Reardan2009.xlsx read successfully.
# File Reardan2010.xlsx read successfully.
# File Reardan2011.xlsx read successfully.
# File Reardan2012.xlsx read successfully.
# File Reardan2013.xlsx read successfully.
# File Reardan2014.xlsx read successfully.
# File Reardan2015.xlsx read successfully.
# File Reardan2016.xlsx read successfully.
# File Reardan2017.xlsx read successfully.
# File Reardan2018.xlsx read successfully.
# File Reardan2019.xlsx read successfully.
# File Reardan2020.xlsx read successfully.
# Files merged successfully into ./vpd\Reardan.xlsx
# File Ritzville2004.xlsx read successfully.
# File Ritzville2005.xlsx read successfully.
# File Ritzville2006.xlsx read successfully.
# File Ritzville2007.xlsx read successfully.
# File Ritzville2008.xlsx read successfully.
# File Ritzville2009.xlsx read successfully.
# File Ritzville2010.xlsx read successfully.
# File Ritzville2011.xlsx read successfully.
# File Ritzville2012.xlsx read successfully.
# File Ritzville2013.xlsx read successfully.
# File Ritzville2014.xlsx read successfully.
# File Ritzville2015.xlsx read successfully.
# File Ritzville2016.xlsx read successfully.
# File Ritzville2017.xlsx read successfully.
# File Ritzville2018.xlsx read successfully.
# File Ritzville2019.xlsx read successfully.
# File Ritzville2020.xlsx read successfully.
# Files merged successfully into ./vpd\Ritzville.xlsx
# File St. John2004.xlsx read successfully.
# File St. John2005.xlsx read successfully.
# File St. John2006.xlsx read successfully.
# File St. John2007.xlsx read successfully.
# File St. John2008.xlsx read successfully.
# File St. John2009.xlsx read successfully.
# File St. John2010.xlsx read successfully.
# File St. John2011.xlsx read successfully.
# File St. John2012.xlsx read successfully.
# File St. John2013.xlsx read successfully.
# File St. John2014.xlsx read successfully.
# File St. John2015.xlsx read successfully.
# File St. John2016.xlsx read successfully.
# File St. John2017.xlsx read successfully.
# File St. John2018.xlsx read successfully.
# File St. John2019.xlsx read successfully.
# File St. John2020.xlsx read successfully.
# Files merged successfully into ./vpd\St. John.xlsx
# File Walla Walla2004.xlsx read successfully.
# File Walla Walla2005.xlsx read successfully.
# File Walla Walla2006.xlsx read successfully.
# File Walla Walla2007.xlsx read successfully.
# File Walla Walla2008.xlsx read successfully.
# File Walla Walla2009.xlsx read successfully.
# File Walla Walla2010.xlsx read successfully.
# File Walla Walla2011.xlsx read successfully.
# File Walla Walla2012.xlsx read successfully.
# File Walla Walla2013.xlsx read successfully.
# File Walla Walla2014.xlsx read successfully.
# File Walla Walla2015.xlsx read successfully.
# File Walla Walla2016.xlsx read successfully.
# File Walla Walla2017.xlsx read successfully.
# File Walla Walla2018.xlsx read successfully.
# File Walla Walla2019.xlsx read successfully.
# File Walla Walla2020.xlsx read successfully.
# Files merged successfully into ./vpd\Walla Walla.xlsx
# File Anatone2004.xlsx read successfully.
# File Anatone2005.xlsx read successfully.
# File Anatone2006.xlsx read successfully.
# File Anatone2007.xlsx read successfully.
# File Anatone2008.xlsx read successfully.
# File Anatone2009.xlsx read successfully.
# File Anatone2010.xlsx read successfully.
# File Anatone2011.xlsx read successfully.
# File Anatone2012.xlsx read successfully.
# File Anatone2013.xlsx read successfully.
# File Anatone2014.xlsx read successfully.
# File Anatone2015.xlsx read successfully.
# File Anatone2016.xlsx read successfully.
# File Anatone2017.xlsx read successfully.
# File Anatone2018.xlsx read successfully.
# File Anatone2019.xlsx read successfully.
# File Anatone2020.xlsx read successfully.
# Files merged successfully into ./vpd\Anatone.xlsx
# File Connell2004.xlsx read successfully.
# File Connell2005.xlsx read successfully.
# File Connell2006.xlsx read successfully.
# File Connell2007.xlsx read successfully.
# File Connell2008.xlsx read successfully.
# File Connell2009.xlsx read successfully.
# File Connell2010.xlsx read successfully.
# File Connell2011.xlsx read successfully.
# File Connell2012.xlsx read successfully.
# File Connell2013.xlsx read successfully.
# File Connell2014.xlsx read successfully.
# File Connell2015.xlsx read successfully.
# File Connell2016.xlsx read successfully.
# File Connell2017.xlsx read successfully.
# File Connell2018.xlsx read successfully.
# File Connell2019.xlsx read successfully.
# File Connell2020.xlsx read successfully.
# Files merged successfully into ./vpd\Connell.xlsx
# File St. Andrews2004.xlsx read successfully.
# File St. Andrews2005.xlsx read successfully.
# File St. Andrews2006.xlsx read successfully.
# File St. Andrews2007.xlsx read successfully.
# File St. Andrews2008.xlsx read successfully.
# File St. Andrews2009.xlsx read successfully.
# File St. Andrews2010.xlsx read successfully.
# File St. Andrews2011.xlsx read successfully.
# File St. Andrews2012.xlsx read successfully.
# File St. Andrews2013.xlsx read successfully.
# File St. Andrews2014.xlsx read successfully.
# File St. Andrews2015.xlsx read successfully.
# File St. Andrews2016.xlsx read successfully.
# File St. Andrews2017.xlsx read successfully.
# File St. Andrews2018.xlsx read successfully.
# File St. Andrews2019.xlsx read successfully.
# File St. Andrews2020.xlsx read successfully.
# Files merged successfully into ./vpd\St. Andrews.xlsx
# File Endicott2004.xlsx read successfully.
# File Endicott2005.xlsx read successfully.
# File Endicott2006.xlsx read successfully.
# File Endicott2007.xlsx read successfully.
# File Endicott2008.xlsx read successfully.
# File Endicott2009.xlsx read successfully.
# File Endicott2010.xlsx read successfully.
# File Endicott2011.xlsx read successfully.
# File Endicott2012.xlsx read successfully.
# File Endicott2013.xlsx read successfully.
# File Endicott2014.xlsx read successfully.
# File Endicott2015.xlsx read successfully.
# File Endicott2016.xlsx read successfully.
# File Endicott2017.xlsx read successfully.
# File Endicott2018.xlsx read successfully.
# File Endicott2019.xlsx read successfully.
# File Endicott2020.xlsx read successfully.
# Files merged successfully into ./vpd\Endicott.xlsx
# File Plaza2004.xlsx read successfully.
# File Plaza2005.xlsx read successfully.
# File Plaza2006.xlsx read successfully.
# File Plaza2007.xlsx read successfully.
# File Plaza2008.xlsx read successfully.
# File Plaza2009.xlsx read successfully.
# File Plaza2010.xlsx read successfully.
# File Plaza2011.xlsx read successfully.
# File Plaza2012.xlsx read successfully.
# File Plaza2013.xlsx read successfully.
# File Plaza2014.xlsx read successfully.
# File Plaza2015.xlsx read successfully.
# File Plaza2016.xlsx read successfully.
# File Plaza2017.xlsx read successfully.
# File Plaza2018.xlsx read successfully.
# File Plaza2019.xlsx read successfully.
# File Plaza2020.xlsx read successfully.
# Files merged successfully into ./vpd\Plaza.xlsx

# %%
###################################################################################################
# I deleted the dates from old file from 1979 to 2003. Save them in old1 file.                    #
#  Just remember that I manaully delete old files and replace them with  old1 files manaully.     #
# This should be done just once.                                                                  #
###################################################################################################

import os
import pandas as pd
dir1 = './old'
dir2 = './old1'
excel_files = os.listdir(dir1)
for file_name in excel_files:
    file_path = os.path.join(dir1, file_name)
    df = pd.read_excel(file_path)
    df['date'] = pd.to_datetime(df['date'])
    df_filtered = df[~df['date'].dt.year.between(1979, 2004)]
    output_file_path = os.path.join(dir2, file_name)
    df_filtered.to_excel(output_file_path, index=False)

# %%
####################################################################
# Concatenate dataframes from old and new variables and save them  #
#                  in 'new' document.                              #
####################################################################



import os
import pandas as pd

# Define the directories containing the Excel files

dir1 = './old'
dir2 = './vpd'
output_dir = './new'  # Directory to save the updated files

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# List of Excel file names (assuming they have the same names in each document)
excel_files = os.listdir(dir1)

for file_name in excel_files:
    # Paths to the corresponding files in each directory
    file1_path = os.path.join(dir1, file_name)
    file2_path = os.path.join(dir2, file_name)
    
    # Check if file exists in both directories
    if not os.path.exists(file2_path):
        print(f"File {file_name} does not exist in {dir2}. Skipping...")
        continue
    
    # Read the Excel files
    df1 = pd.read_excel(file1_path)
    df2 = pd.read_excel(file2_path)
    
    # Find columns that are common between df1 and df2
    common_columns = df1.columns.intersection(df2.columns)

    # Drop the common columns from df2
    df2_dropped = df2.drop(columns=common_columns)

    # Step 2: Concatenate df1 and df2 (horizontally in this case)
    result = pd.concat([df1, df2_dropped], axis=1)
    
    # Save the updated DataFrame to a new Excel file in the output directory
    output_file_path = os.path.join(output_dir, file_name)
    result.to_excel(output_file_path, index = False)
    print(f"Updated file saved to {output_file_path}")

print("All files have been updated and saved.")
# Out:
# Updated file saved to ./new\Almira.xlsx
# Updated file saved to ./new\Bickleton.xlsx
# Updated file saved to ./new\Connell.xlsx
# Updated file saved to ./new\Dayton.xlsx
# Updated file saved to ./new\Dusty.xlsx
# Updated file saved to ./new\Endicott.xlsx
# Updated file saved to ./new\Fairfield.xlsx
# Updated file saved to ./new\Farmington.xlsx
# Updated file saved to ./new\Horse Heaven.xlsx
# Updated file saved to ./new\Lamont.xlsx
# Updated file saved to ./new\Lind.xlsx
# Updated file saved to ./new\Mayview.xlsx
# Updated file saved to ./new\Plaza.xlsx
# Updated file saved to ./new\Pullman.xlsx
# Updated file saved to ./new\Reardan.xlsx
# Updated file saved to ./new\Ritzville.xlsx
# Updated file saved to ./new\St. Andrews.xlsx
# Updated file saved to ./new\St. John.xlsx
# Updated file saved to ./new\Walla Walla.xlsx
# All files have been updated and saved.

# %%
import os
import pandas as pd


#############################################################
#       This part is for merging the columns                #
#       of all the new data extracted from netcdfs          #
#############################################################

# Define the directories containing the Excel files
dir1 = './pr/'
dir2 = './tmin/'
dir3 = './tmax/'
output_dir = './merge_updates/'  # Directory to save the updated files

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# List of Excel file names (assuming they have the same names in each document)
excel_files = os.listdir(dir1)

for file_name in excel_files:
    # Paths to the corresponding files in each directory
    file1_path = os.path.join(dir1, file_name)
    file2_path = os.path.join(dir2, file_name)
    file3_path = os.path.join(dir3, file_name)
    
    # Read the Excel files
    df1 = pd.read_excel(file1_path)
    df2 = pd.read_excel(file2_path)
    df3 = pd.read_excel(file3_path)
    
    # Extract the second column from the files in the second and third documents
    column2_from_df2 = df2.iloc[:, 1]
    column2_from_df3 = df3.iloc[:, 1]
    
    # Add these columns to the corresponding file in the first document
    df1['tmin'] = column2_from_df2
    df1['tmax'] = column2_from_df3
    
    # Save the updated DataFrame to a new Excel file in the output directory
    output_file_path = os.path.join(output_dir, file_name)
    df1.to_excel(output_file_path, index=False)
    
    print(f"Updated file saved to {output_file_path}")

print("All files have been updated and saved.")
# Out:
# Updated file saved to ./merge_updates/Almira.xlsx
# Updated file saved to ./merge_updates/Anatone.xlsx
# Updated file saved to ./merge_updates/Bickleton.xlsx
# Updated file saved to ./merge_updates/Colfax.xlsx
# Updated file saved to ./merge_updates/Connell.xlsx
# Updated file saved to ./merge_updates/Dayton.xlsx
# Updated file saved to ./merge_updates/Dusty.xlsx
# Updated file saved to ./merge_updates/Endicott.xlsx
# Updated file saved to ./merge_updates/Fairfield.xlsx
# Updated file saved to ./merge_updates/Farmington.xlsx
# Updated file saved to ./merge_updates/Horse Heaven.xlsx
# Updated file saved to ./merge_updates/Lamont.xlsx
# Updated file saved to ./merge_updates/Lind.xlsx
# Updated file saved to ./merge_updates/Mayview.xlsx
# Updated file saved to ./merge_updates/Palouse.xlsx
# Updated file saved to ./merge_updates/Plaza.xlsx
# Updated file saved to ./merge_updates/Pullman.xlsx
# Updated file saved to ./merge_updates/Reardan.xlsx
# Updated file saved to ./merge_updates/Ritzville.xlsx
# Updated file saved to ./merge_updates/St. Andrews.xlsx
# Updated file saved to ./merge_updates/St. John.xlsx
# Updated file saved to ./merge_updates/Walla Walla.xlsx
# All files have been updated and saved.

# %%
#############################################################
#       This part is for merging the columns                #
#       from new data to the bottom rows of the old data    #
#       with the same column name                           #
#############################################################





import os
import pandas as pd

# Define the directories containing the Excel files

dir1 = './washington'
dir2 = './merge_updates'

output_dir = './final'  # Directory to save the updated files

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# List of Excel file names (assuming they have the same names in each document)
excel_files = os.listdir(dir1)

for file_name in excel_files:
    # Paths to the corresponding files in each directory
    file1_path = os.path.join(dir1, file_name)
    file2_path = os.path.join(dir2, file_name)
    
    # Check if file exists in both directories
    if not os.path.exists(file2_path):
        print(f"File {file_name} does not exist in {dir2}. Skipping...")
        continue
    
    # Read the Excel files
    df1 = pd.read_excel(file1_path)
    df2 = pd.read_excel(file2_path)
    
    # Concatenate the DataFrames based on the same column names
    merged_df = pd.concat([df1, df2], axis=0, join='inner')
    
    # Reset the index of the merged DataFrame
    merged_df.reset_index(drop=True, inplace=True)
    
    # Save the updated DataFrame to a new Excel file in the output directory
    output_file_path = os.path.join(output_dir, file_name)
    merged_df.to_excel(output_file_path, index=False)
    
    print(f"Updated file saved to {output_file_path}")

print("All files have been updated and saved.")
# Out:
# Updated file saved to ./final\Almira.xlsx
# Updated file saved to ./final\Anatone.xlsx
# Updated file saved to ./final\Bickleton.xlsx
# Updated file saved to ./final\Colfax.xlsx
# Updated file saved to ./final\Connell.xlsx
# Updated file saved to ./final\Dayton.xlsx
# Updated file saved to ./final\Dusty.xlsx
# Updated file saved to ./final\Endicott.xlsx
# Updated file saved to ./final\Fairfield.xlsx
# Updated file saved to ./final\Farmington.xlsx
# Updated file saved to ./final\Horse Heaven.xlsx
# Updated file saved to ./final\Lamont.xlsx
# Updated file saved to ./final\Lind.xlsx
# Updated file saved to ./final\Mayview.xlsx
# Updated file saved to ./final\Palouse.xlsx
# Updated file saved to ./final\Plaza.xlsx
# Updated file saved to ./final\Pullman.xlsx
# Updated file saved to ./final\Reardan.xlsx
# Updated file saved to ./final\Ritzville.xlsx
# Updated file saved to ./final\St. Andrews.xlsx
# Updated file saved to ./final\St. John.xlsx
# Updated file saved to ./final\Walla Walla.xlsx
# All files have been updated and saved.
